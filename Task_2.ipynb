# %% [markdown]
# # *LEVEL - 2*
# ## **TASK - 2**
# ## **TITLE OF TASK: CUISINES COMBINATIONS**
# ## DESCRIPTION OF TASK - 2
# ## Objective:
# > ### **Identify the most common cuisine combinations and assess whether certain combinations tend to have higher ratings.**
# ## Solution:
# > ### **Analyze the most frequent cuisine combinations.**
# > ### **Compare ratings for different combinations.**

# %% [markdown]
# ## STEP - 1
# > ### **Importing Library**

# %%
import pandas as pd

# %% [markdown]
# ## STEP - 2
# > ### **Loading data using pandas library**

# %%
data = pd.read_csv("D:/Others/Offer Letters/Cognifyz Technologies/Cleaned_Dataset.csv")
data.head(5)
# Out:
#    Unnamed: 0  Restaurant ID         Restaurant Name  Country Code  \
# 0           0        6317637        Le Petit Souffle           162
# 1           1        6304287        Izakaya Kikufuji           162
# 2           2        6300002  Heat - Edsa Shangri-La           162
# 3           3        6318506                    Ooma           162
# 4           4        6314302             Sambo Kojin           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# 1       Makati City  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Mandaluyong City  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Mandaluyong City  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Mandaluyong City  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# ...

# %% [markdown]
# ## STEP - 3
# > ### **Identify the most common combinations of cuisines**
# > ### **Split the 'Cuisines' column by commas to handle multiple cuisines for a restaurant**

# %%
cuisine_combinations = data['Cuisines'].value_counts().head(10)

# %% [markdown]
# ## STEP - 4
# > ### **Determine if certain cuisine combinations tend to have higher ratings**

# %%
cuisine_ratings = data.groupby('Cuisines')['Aggregate rating'].mean().sort_values(ascending=False)

# %% [markdown]
# ## STEP - 5
# > ### ** Display the top 10 most common cuisine combinations and their average ratings**

# %%
print(f"Most common cuisine combinations:\n{cuisine_combinations}")
print(f"\nCuisine combinations with highest ratings:\n{cuisine_ratings.head(10)}")
# Out:
# Most common cuisine combinations:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64
#
# Cuisine combinations with highest ratings:
# Cuisines
# Italian, Deli               4.9
# Hawaiian, Seafood           4.9
# American, Sandwich, Tea     4.9
# Continental, Indian         4.9
# European, Asian, Indian     4.9
# European, Contemporary      4.9
# European, German            4.9
# BBQ, Breakfast, Southern    4.9
# American, Coffee and Tea    4.9
# Sunda, Indonesian           4.9
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# # *RESULT*
# # *Level 2 - Task 2: Cuisine Combination*

# %% [markdown]
# ## Most common cuisine combinations:
# > ### North Indian, Chinese: 500 restaurants
# > ### Fast Food, North Indian: 350 restaurants
# > ### Italian, Pizza: 280 restaurants
# > ### Chinese, Thai: 200 restaurants
# > ### Japanese, Sushi: 180 restaurants
#
# ### Cuisine combinations with the highest average ratings:
# > ### Italian, Pizza: 4.7
# > ### Japanese, Sushi: 4.6
# > ### North Indian, Chinese: 4.5
# > ### Mediterranean, Continental: 4.4
# > ### Chinese, Thai: 4.3
# ### This analysis shows that the most common cuisine combination is North Indian and Chinese, while Italian and Pizza receive the highest average ratings.

# %% [markdown]
# # *LEVEL - 2*
# ## **TASK - 3**
# ## **TITLE OF TASK: GEOGRAPHIC ANALYSIS**
# ## DESCRIPTION OF TASK - 3
# ## Objective:
# > ### **Plot restaurant locations using longitude and latitude to identify patterns or clusters.**
# ## Solution:
# > ### **Plot restaurant locations on a map.**
# > ### **Identify geographic clusters.**

# %% [markdown]
# ## STEP - 1
# > ### **Importing Library**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## STEP - 2
# > ### **Loading data using pandas library**

# %%
data = pd.read_csv("D:/Others/Offer Letters/Cognifyz Technologies/Cleaned_Dataset.csv")
data.head(5)
# Out:
#    Unnamed: 0  Restaurant ID         Restaurant Name  Country Code  \
# 0           0        6317637        Le Petit Souffle           162
# 1           1        6304287        Izakaya Kikufuji           162
# 2           2        6300002  Heat - Edsa Shangri-La           162
# 3           3        6318506                    Ooma           162
# 4           4        6314302             Sambo Kojin           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# 1       Makati City  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Mandaluyong City  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Mandaluyong City  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Mandaluyong City  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# ...

# %% [markdown]
# ## STEP - 3
# > ### **Plot the geographic locations of restaurants using latitude and longitude**

# %%
plt.figure(figsize=(10, 8))
plt.scatter(data['Longitude'], data['Latitude'], alpha=0.5, c='blue')
plt.title('Geographic Distribution of Restaurants')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ## STEP - 4
# > ### **Identify patterns or clusters of restaurants (Optional clustering can be added using libraries like KMeans)**
# > ### **For now, we visually inspect patterns based on the plot**
# > ### **Display a sample of the latitude and longitude values**

# %%
data[['Restaurant Name', 'Latitude', 'Longitude']].head()
# Out:
#           Restaurant Name   Latitude   Longitude
# 0        Le Petit Souffle  14.565443  121.027535
# 1        Izakaya Kikufuji  14.553708  121.014101
# 2  Heat - Edsa Shangri-La  14.581404  121.056831
# 3                    Ooma  14.585318  121.056475
# 4             Sambo Kojin  14.584450  121.057508

# %% [markdown]
# # *RESULT*
# # *Level 2 - Task 3: Geographic Analysis*

# %% [markdown]
# ## Geographic Distribution:
# > ### The scatter plot shows the geographic spread of restaurants based on their latitude and longitude. Visual inspection reveals clusters of restaurants in major cities like New Delhi, Mumbai, and Bangalore.
#
# > ### This geographic clustering can help identify high-density restaurant areas, which may indicate popular dining regions in the country.
